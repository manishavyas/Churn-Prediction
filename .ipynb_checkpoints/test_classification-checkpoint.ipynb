# %%
# import required packages

import numpy as np
import pandas as pd

# %%
import xgboost as xgb

# %%
churn_df = pd.read_csv('analysis_data.csv')

# %%
churn_df.head()
# Out:
#    Avg_actual_amount_paid  Avg_payment_plan_days  Avg_plan_list_price   age  \
# 0                    99.0                   30.0                 99.0  -1.0
# 1                   149.0                   30.0                149.0  26.0
# 2                   149.0                   30.0                149.0  -1.0
# 3                   149.0                   30.0                149.0  21.0
# 4                   149.0                   30.0                149.0  32.0
#
#    count_201609  count_201610  count_201611  count_201612  count_201701  \
# 0           0.0           0.0          15.0          31.0          30.0
# 1          28.0          30.0          29.0          31.0          31.0
# 2          18.0          17.0          17.0          24.0          27.0
# 3          27.0          30.0          26.0          26.0          27.0
# 4          25.0          22.0          19.0          18.0          27.0
#
#    count_201702          ...           total_secs_mean_201611  \
# ...

# %%
churn_df.describe()
# Out:
#        Avg_actual_amount_paid  Avg_payment_plan_days  Avg_plan_list_price  \
# count           810078.000000          810078.000000        810078.000000
# mean               148.279001              33.822303           148.627093
# std                131.609932              30.747852           131.563776
# min                  0.000000               1.000000             0.000000
# 25%                 99.000000              30.000000            99.000000
# 50%                149.000000              30.000000           149.000000
# 75%                149.000000              30.000000           149.000000
# max               2000.000000             450.000000          2000.000000
#
#                  age   count_201609   count_201610   count_201611  \
# count  810058.000000  810078.000000  810078.000000  810078.000000
# mean       12.987312      13.977840      15.160499      15.153353
# std        16.477445      10.514483      10.901549      10.519040
# ...

# %%
for i in churn_df.columns:
    print(i)
# Out:
# Avg_actual_amount_paid
# Avg_payment_plan_days
# Avg_plan_list_price
# age
# count_201609
# count_201610
# count_201611
# count_201612
# count_201701
# count_201702
# gender
# is_churn
# latest_actual_amount_paid
# latest_is_auto_renew
# latest_is_cancel
# latest_membership_expire_date
# latest_payment_plan_days
# latest_plan_list_price
# latest_transaction_date
# msno
# num_100_mean_201609
# num_100_mean_201610
# num_100_mean_201611
# num_100_mean_201612
# num_100_mean_201701
# num_100_mean_201702
# num_100_std_201609
# num_100_std_201610
# num_100_std_201611
# num_100_std_201612
# num_100_std_201701
# num_100_std_201702
# num_25_mean_201609
# num_25_mean_201610
# num_25_mean_201611
# num_25_mean_201612
# num_25_mean_201701
# num_25_mean_201702
# num_25_std_201609
# num_25_std_201610
# num_25_std_201611
# num_25_std_201612
# num_25_std_201701
# num_25_std_201702
# num_50_mean_201609
# num_50_mean_201610
# num_50_mean_201611
# num_50_mean_201612
# num_50_mean_201701
# ...

# %%
churn_df.groupby(['is_churn'])['is_churn'].count()
# Out:
# is_churn
# 0    782529
# 1     27549
# Name: is_churn, dtype: int64

# %%
churn_df.is_churn.value_counts()
# Out:
# 0    782529
# 1     27549
# Name: is_churn, dtype: int64
